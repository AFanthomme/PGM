# %%
from EM_procedure import *
import numpy as np
import dynamical_systems as dyn
import tqdm
import matplotlib.pyplot as plt

# %%
def sin_flow(x):
    return np.sin(np.pi*x)

def no_drive(n_hidden):
    return lambda _: np.zeros(n_hidden)

dummy_obs = lambda x: x

d = dyn.dynamical_system(n_hidden=1, n_inputs=0, n_outputs=3, flow_function=sin_flow, driving_function=no_drive(1),
                             output_function=dummy_obs)

# %%
output, true_hidden = d.generate_trajectory()
# Out:
# [0.97805264] []
# [0.97805264]
# [-0.0024222] []
# [-0.0024222]
# [-0.02848345] []
# [-0.02848345]
# [-0.102487] []
# [-0.102487]
# [-0.28300271] []
# [-0.28300271]
# [-0.84008869] []
# [-0.84008869]
# [-0.43489338] []
# [-0.43489338]
# [-0.96805422] []
# [-0.96805422]
# [-0.1414969] []
# [-0.1414969]
# [-0.41165709] []
# [-0.41165709]
# [-0.93970473] []
# [-0.93970473]
# [-0.17603852] []
# [-0.17603852]
# [-0.59429326] []
# [-0.59429326]
# [-0.911587] []
# [-0.911587]
# [-0.29373722] []
# [-0.29373722]
# [-0.89684646] []
# [-0.89684646]
# [-0.3033924] []
# [-0.3033924]
# [-0.75817609] []
# [-0.75817609]
# [-0.70208129] []
# [-0.70208129]
# [-0.71876716] []
# [-0.71876716]
# [-0.760218] []
# [-0.760218]
# [-0.66899623] []
# [-0.66899623]
# [-0.87266135] []
# [-0.87266135]
# [-0.34754615] []
# [-0.34754615]
# [-0.87272646] []
# [-0.87272646]
# [-0.40642827] []
# [-0.40642827]
# [-0.94419076] []
# [-0.94419076]
# [-0.12981867] []
# [-0.12981867]
# [-0.45351353] []
# [-0.45351353]
# [-1.03834542] []
# [-1.03834542]
# [0.13083571] []
# [0.13083571]
# [0.40953947] []
# [0.40953947]
# [0.93639408] []
# [0.93639408]
# [0.17061258] []
# [0.17061258]
# [0.53992595] []
# [0.53992595]
# [1.08214225] []
# [1.08214225]
# [-0.21883276] []
# [-0.21883276]
# [-0.66713492] []
# [-0.66713492]
# [-0.8590422] []
# [-0.8590422]
# [-0.54112213] []
# [-0.54112213]
# [-0.95874729] []
# [-0.95874729]
# [-0.14922277] []
# [-0.14922277]
# [-0.37459908] []
# [-0.37459908]
# [-1.06187105] []
# [-1.06187105]
# [0.23790707] []
# [0.23790707]
# [0.65449154] []
# [0.65449154]
# [0.93228263] []
# [0.93228263]
# [0.28122747] []
# [0.28122747]
# [0.78781626] []
# [0.78781626]
# [0.63351694] []
# [0.63351694]
# [0.98598058] []
# [0.98598058]
# [0.00179585] []
# [0.00179585]
# [-0.01530431] []
# [-0.01530431]
# [0.03191612] []
# [0.03191612]
# [0.08577372] []
# [0.08577372]
# [0.32850755] []
# [0.32850755]
# [0.85967531] []
# [0.85967531]
# [0.48026085] []
# [0.48026085]
# [0.87883735] []
# [0.87883735]
# [0.33220946] []
# [0.33220946]
# [0.94577624] []
# [0.94577624]
# [0.20612819] []
# [0.20612819]
# [0.59713351] []
# [0.59713351]
# [0.96805366] []
# [0.96805366]
# [0.09119705] []
# [0.09119705]
# [0.2239487] []
# [0.2239487]
# [0.66950836] []
# [0.66950836]
# [0.90577545] []
# [0.90577545]
# [0.23225107] []
# [0.23225107]
# [0.6773603] []
# [0.6773603]
# [0.97221037] []
# [0.97221037]
# [0.10995917] []
# [0.10995917]
# [0.35733741] []
# [0.35733741]
# [0.89858957] []
# [0.89858957]
# [0.20495494] []
# [0.20495494]
# [0.542586] []
# [0.542586]
# [0.92986686] []
# [0.92986686]
# [0.23998762] []
# [0.23998762]
# [0.76022694] []
# [0.76022694]
# [0.71676489] []
# [0.71676489]
# [0.76623673] []
# [0.76623673]
# [0.64327604] []
# [0.64327604]
# [0.87758657] []
# [0.87758657]
# [0.36613781] []
# [0.36613781]
# [0.8767812] []
# [0.8767812]
# [0.44053918] []
# [0.44053918]
# [0.96232868] []
# [0.96232868]
# [0.13374313] []
# [0.13374313]
# [0.42916297] []
# [0.42916297]
# [1.01422194] []
# [1.01422194]
# [-0.04253598] []
# [-0.04253598]
# [-0.15656639] []
# [-0.15656639]
# [-0.4798129] []
# [-0.4798129]
# [-0.98329991] []
# [-0.98329991]
# [-0.05387255] []
# [-0.05387255]
# [-0.11587933] []
# [-0.11587933]
# [-0.3883745] []
# [-0.3883745]
# [-0.89068356] []
# [-0.89068356]
# [-0.35940185] []
# [-0.35940185]
# [-0.9734704] []
# [-0.9734704]

# %%
n_rbf = 20
n_hidden = 1
n_outputs = 3
max_iter = 10

# %%
EM = EM_container(output, np.linspace(-5,5,n_rbf).reshape(n_rbf,n_hidden), np.array([np.eye(n_hidden) for i in range(n_rbf)]), np.zeros((n_hidden,n_hidden)), np.zeros(n_hidden),np.zeros((n_outputs,n_hidden)), np.zeros(n_outputs))

# %%
for i in tqdm.tqdm(range(max_iter)):
    EM.E_step()
    EM.M_step()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#  10%|█         | 1/10 [00:02<00:26,  2.92s/it]
#  20%|██        | 2/10 [00:06<00:24,  3.07s/it]
#  30%|███       | 3/10 [00:09<00:21,  3.10s/it]
#  40%|████      | 4/10 [00:11<00:17,  2.96s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-1924f46701ad> in <module>()
#       4     plt.plot(np.linspace(-5,5,200),[EM.f_estimator(x)[0][0] for x in np.linspace(-5,5,200)])
#       5     plt.show()
# ----> 6     EM.E_step()
#       7     EM.M_step()
#
# /home/cosmo/Documents/scolarite/MVA/S1/PGM/project/PGM/EM_procedure.py in E_step(self)
#      31         #print(self.g_coords.shape)
#      32         ukf = AdditiveUnscentedKalmanFilter(self.f_estimator, self.g_estimator, transition_covariance=self.w_cov, observation_covariance=self.v_cov)
# ---> 33         self.hidden_sequence = ukf.smooth(self.output_sequence)[0]
#      34
#      35
#
# /usr/lib/python3.6/site-packages/pykalman/unscented.py in smooth(self, Z)
#    1347         )
#    1348
# -> 1349         (filtered_state_means, filtered_state_covariances) = self.filter(Z)
#    1350         (smoothed_state_means, smoothed_state_covariances) = (
#    1351             additive_unscented_smoother(
#
# /usr/lib/python3.6/site-packages/pykalman/unscented.py in filter(self, Z)
#    1208                 transition_functions, observation_functions,
#    1209                 transition_covariance, observation_covariance,
# -> 1210                 Z
#    1211             )
#    1212         )
#
# /usr/lib/python3.6/site-packages/pykalman/unscented.py in additive_unscented_filter(mu_0, sigma_0, f, g, Q, R, Z)
#     600             (_, moments_pred) = (
#     601                 unscented_filter_predict(
# --> 602                     transition_function, points_state, sigma_transition=Q
#     603                 )
#     604             )
#
# /usr/lib/python3.6/site-packages/pykalman/unscented.py in unscented_filter_predict(transition_function, points_state, points_transition, sigma_transition)
#     335         unscented_transform(
#     336             points_state, transition_function,
# --> 337             points_noise=points_transition, sigma_noise=sigma_transition
#     338         )
#     339     )
#
# /usr/lib/python3.6/site-packages/pykalman/unscented.py in unscented_transform(points, f, points_noise, sigma_noise)
#     144     if f is not None:
#     145         if points_noise is None:
# --> 146             points_pred = [f(points[i]) for i in range(n_points)]
#     147         else:
#     148             points_noise = points_noise.points
#
# /usr/lib/python3.6/site-packages/pykalman/unscented.py in <listcomp>(.0)
#     144     if f is not None:
#     145         if points_noise is None:
# --> 146             points_pred = [f(points[i]) for i in range(n_points)]
#     147         else:
#     148             points_noise = points_noise.points
#
# /home/cosmo/Documents/scolarite/MVA/S1/PGM/project/PGM/EM_procedure.py in <lambda>(x)
#      92
#      93         self.g_estimator = lambda x: np.sum(np.dot(self.g_coords.T, self.rho(x))) + np.dot(self.linear_g, x) + self.bias_g
# ---> 94         self.f_estimator = lambda x: np.sum(np.dot(self.f_coords.T, self.rho(x))) + np.dot(self.linear_f, x) + self.bias_f
#      95
#      96         #return f_estimator, g_estimator, self.w_cov, self.v_cov
#
# /home/cosmo/Documents/scolarite/MVA/S1/PGM/project/PGM/EM_procedure.py in <lambda>(x)
#      10         self.basis_functions = [lambda x: multivariate_normal.pdf(x, mean=rbf_centers[i, :], cov= rbf_covs[i, :,:]) for i
#      11                                 in range(len(rbf_centers))]
# ---> 12         self.rho = lambda x: np.array([rho(x) for rho in self.basis_functions])
#      13         self.f_coords = np.random.randn(self.n_rbfs, self.n_hidden) # List of coefs for representing f (self.n_rbfs x self.n_hidden)
#      14         self.linear_f = A  # Matrix of the linear part of f (self.n_hidden x self.n_hidden)
#
# /home/cosmo/Documents/scolarite/MVA/S1/PGM/project/PGM/EM_procedure.py in <listcomp>(.0)
#      10         self.basis_functions = [lambda x: multivariate_normal.pdf(x, mean=rbf_centers[i, :], cov= rbf_covs[i, :,:]) for i
#      11                                 in range(len(rbf_centers))]
# ---> 12         self.rho = lambda x: np.array([rho(x) for rho in self.basis_functions])
#      13         self.f_coords = np.random.randn(self.n_rbfs, self.n_hidden) # List of coefs for representing f (self.n_rbfs x self.n_hidden)
#      14         self.linear_f = A  # Matrix of the linear part of f (self.n_hidden x self.n_hidden)
#
# /home/cosmo/Documents/scolarite/MVA/S1/PGM/project/PGM/EM_procedure.py in <lambda>(x)
#       8         self.n_hidden = A.shape[0]
#       9         self.n_outputs = C.shape[0]
# ---> 10         self.basis_functions = [lambda x: multivariate_normal.pdf(x, mean=rbf_centers[i, :], cov= rbf_covs[i, :,:]) for i
#      11                                 in range(len(rbf_centers))]
#      12         self.rho = lambda x: np.array([rho(x) for rho in self.basis_functions])
#
# /usr/lib/python3.6/site-packages/scipy/stats/_multivariate.py in pdf(self, x, mean, cov, allow_singular)
#     500
#     501         """
# --> 502         dim, mean, cov = self._process_parameters(None, mean, cov)
#     503         x = self._process_quantiles(x, dim)
#     504         psd = _PSD(cov, allow_singular=allow_singular)
#
# /usr/lib/python3.6/site-packages/scipy/stats/_multivariate.py in _process_parameters(self, dim, mean, cov)
#     385         if dim == 1:
#     386             mean.shape = (1,)
# --> 387             cov.shape = (1, 1)
#     388
#     389         if mean.ndim != 1 or mean.shape[0] != dim:
#
# KeyboardInterrupt:

# %%
plt.figure(figsize = (10,10))
plt.plot(true_hidden[:-1],true_hidden[1:],'o')
plt.plot(np.linspace(-5,5,200),[EM.f_estimator(x)[0][0] for x in np.linspace(-5,5,200)])
plt.show()

# %%
EM.f_coords
# Out:
# array([[-5.61695069e-33],
#        [-5.61695069e-33],
#        [-5.61695069e-33],
#        [-5.61695069e-33],
#        [-5.61695069e-33],
#        [-5.61695069e-33],
#        [-5.61695069e-33],
#        [-5.61695069e-33],
#        [-5.61695069e-33],
#        [-5.61695069e-33],
#        [-5.61695069e-33],
#        [-5.61695069e-33],
#        [-5.61695069e-33],
#        [-5.61695069e-33],
#        [-5.61695069e-33],
#        [-5.61695069e-33],
#        [-5.61695069e-33],
#        [-5.61695069e-33],
#        [-5.61695069e-33],
#        [-5.61695069e-33]])
